# %%
#======================

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch.nn.functional as F

# %%
defence = pd.read_csv("US-defence.csv")

# %%
defence #finish the GD column
# Out:
#     Year  Lockheed Martin (Billion USD)  General Dynamics (Billion USD)
# 0   1994                           22.9                              22
# 1   1995                           22.8                               6
# 2   1996                           26.8                               6
# 3   1997                           28.0                               6
# 4   1998                           26.0                               6
# 5   1999                           25.0                               6
# 6   2000                           24.5                               6
# 7   2001                           24.0                               6
# 8   2002                           26.5                               6
# 9   2003                           31.8                               6
# 10  2004                           35.5                               6
# 11  2005                           37.7                               7
# ...

# %%
df['General Dynamics (Billion USD)'][0] = 22
df['General Dynamics (Billion USD)'][1] = 22
df['General Dynamics (Billion USD)'][2] = 22
df['General Dynamics (Billion USD)'][3] = 22
df['General Dynamics (Billion USD)'][4] = 22
df['General Dynamics (Billion USD)'][5] = 22
df['General Dynamics (Billion USD)'][6] = 22
df['General Dynamics (Billion USD)'][7] = 22
df['General Dynamics (Billion USD)'][8] = 22
df['General Dynamics (Billion USD)'][9] = 22
df['General Dynamics (Billion USD)'][10] = 22
df['General Dynamics (Billion USD)'][11] = 22
df['General Dynamics (Billion USD)'][12] = 22
df['General Dynamics (Billion USD)'][13] = 22
df['General Dynamics (Billion USD)'][14] = 22
df['General Dynamics (Billion USD)'][15] = 22
df['General Dynamics (Billion USD)'][16] = 22
# Out:
# /var/folders/b4/k49qxtzd54j0nr06tbdktp9r0000gn/T/ipykernel_48122/2139309454.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['General Dynamics (Billion USD)'][0] = 22

# %%
oil = pd.read_csv("oil_reserves_per_country.csv", index_col=0)
#oil.to_csv("oil_reserves_per_country.csv" , index=False)
oil
# Out:
#          Country  Oil Reserves (Barrels)  Percentage of World Reserves
# 0      Venezuela            299953000000                       18.2000
# 1   Saudi Arabia            266578000000                       16.2000
# 2         Canada            170863000000                       10.4000
# 3           Iran            157530000000                        9.5000
# 4           Iraq            143069000000                        8.7000
# ..           ...                     ...                           ...
# 93        Jordan                 1000000                        0.0001
# 94      Barbados                 2315000                        0.0001
# 95        Taiwan                 2380000                        0.0001
# 96      Ethiopia                  428000                        0.0000
# 97       Morocco                  684000                        0.0000
#
# [98 rows x 3 columns]

# %%
terror = pd.read_csv("terrorist-attacks.csv", index_col=0)
#terror.to_csv("terrorist-attacks.csv", index=False)
terror
# Out:
#            Entity  Year  Terrorist attacks
# 0     Afghanistan  1994                  9
# 1     Afghanistan  1995                  6
# 2     Afghanistan  1996                  4
# 3     Afghanistan  1997                  1
# 4     Afghanistan  1998                  1
# ...           ...   ...                ...
# 6015     Zimbabwe  2017                  3
# 6016     Zimbabwe  2018                  2
# 6017     Zimbabwe  2019                  2
# 6018     Zimbabwe  2020                  1
# 6019     Zimbabwe  2021                  0
#
# [6020 rows x 3 columns]

# %%
terror_oil = pd.read_csv("terror_and_oil.csv", index_col = 0)
#terror_oil.to_csv("terrorist-attacks.csv", index=False)
terror_oil[terror_oil['Entity']=="China"]
# Out:
#     Entity  Year  Terrorist attacks  Oil Reserves (Barrels)  \
# 588  China  1994                 13             25132122000
# 589  China  1995                  8             25132122000
# 590  China  1996                 62             25132122000
# 591  China  1997                 18             25132122000
# 592  China  1998                  2             25132122000
# 593  China  1999                  2             25132122000
# 594  China  2000                  4             25132122000
# 595  China  2001                 12             25132122000
# 596  China  2002                  2             25132122000
# 597  China  2003                  3             25132122000
# 598  China  2004                  2             25132122000
# 599  China  2005                  1             25132122000
# 600  China  2006                  0             25132122000
# 601  China  2007                  0             25132122000
# 602  China  2008                 20             25132122000
# ...
